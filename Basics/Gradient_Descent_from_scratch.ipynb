# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
df.shape
# Out:
# (28, 3)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df[['age', 'affordibility']], df.bought_insurance, test_size=0.2, random_state=25)#20% of the dataset is test

# %%
len(X_train)
# Out:
# 22

# %% [markdown]
# 22 of them are for training, 6 of them are for testing.

# %%
X_train_scaled = X_train.copy()
X_train_scaled['age'] = X_train_scaled['age'] / 100

X_test_scaled = X_test.copy()
X_test_scaled['age'] = X_test_scaled['age'] / 100

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
model = keras.Sequential([
    keras.layers.Dense(1, input_shape=(2,), activation='sigmoid', kernel_initializer='ones', bias_initializer='zeros')#weight starts from 1, bias starts from 0
])

model.compile(optimizer = 'adam',
              loss='binary_crossentropy', #Log-loss because of logistic regression
            metrics=['accuracy'])
model.fit(X_train_scaled, y_train, epochs=5000)
# Out:
# Epoch 1/5000
# 1/1 [==============================] - 0s 259ms/step - loss: 0.6611 - accuracy: 0.5455
# Epoch 2/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6608 - accuracy: 0.5455
# Epoch 3/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6605 - accuracy: 0.5455
# Epoch 4/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6603 - accuracy: 0.5455
# Epoch 5/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6600 - accuracy: 0.5455
# Epoch 6/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6598 - accuracy: 0.5455
# Epoch 7/5000
# 1/1 [==============================] - 0s 998us/step - loss: 0.6595 - accuracy: 0.5455
# Epoch 8/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6592 - accuracy: 0.5455
# Epoch 9/5000
# 1/1 [==============================] - 0s 2ms/step - loss: 0.6590 - accuracy: 0.5455
# Epoch 10/5000
# ...

# %%
model.evaluate(X_test_scaled, y_test)
# Out:
# 1/1 [==============================] - 0s 85ms/step - loss: 0.3569 - accuracy: 0.8333
# [0.3569333255290985, 0.8333333134651184]

# %%
X_test_scaled
# Out:
#      age  affordibility
# 2   0.47              1
# 10  0.18              1
# 21  0.26              0
# 11  0.28              1
# 14  0.49              1
# 9   0.61              1

# %%
model.predict(X_test_scaled)
# Out:
# array([[0.76880145],
#        [0.39354372],
#        [0.22252706],
#        [0.53270483],
#        [0.7882227 ],
#        [0.87978363]], dtype=float32)

# %%
y_test
# Out:
# 2     1
# 10    0
# 21    0
# 11    0
# 14    1
# 9     1
# Name: bought_insurance, dtype: int64

# %%
coef, intercept = model.get_weights()
coef, intercept
# Out:
# (array([[5.634472],
#         [1.269317]], dtype=float32),
#  array([-2.7159626], dtype=float32))

# %% [markdown]
# This means w1 = 5.63, w2 = 1.269, and bias=-2.715

# %%
def sigmoid(x):
    import math
    return 1 / (1 + math.exp(-x))
sigmoid(18)
# Out:
# 0.9999999847700205

# %%
def prediction_function(age, affordibility): #From scratch
    weighted_sum = coef[0] * age + coef[1] * affordibility + intercept
    return sigmoid(weighted_sum)

# %%
prediction_function(.47, 1) #Gives the same prediction
# Out:
# 0.7688014657789716

# %%
prediction_function(.18, 1) #Gives the same prediction
# Out:
# 0.39354370891763535

# %%
#Now gradient descent from scratch

def log_loss(y_true, y_predicted):
    epsilon=1e-15
    y_predicted_new = [max(i, epsilon) for i in y_predicted]
    y_predicted_new = [min(i, 1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean(y_true * np.log(y_predicted_new) + (1-y_true) * np.log(1-y_predicted_new))

# %%
def sigmoid_numpy(X): #Instead of taking 1 value, this function takes an array
    return 1 / (1 + np.exp(-X))

sigmoid_numpy(np.array([12, 0, 1]))
# Out:
# array([0.99999386, 0.5       , 0.73105858])

# %%
class myNN:
    def __init__(self): #Constructor
        self.w1 = 1 #class member
        self.w2 = 1
        self.bias = 0
    
    def fit(self, X, y, epochs, loss_threshold):
        self.w1, self.w2, self.bias = self.gradient_descent(X['age'], X['affordibility'], y, epochs, loss_threshold)
    
    def predict(self, X_test):
        weighted_sum = self.w1 * X_test['age'] + self.w2 * X_test['affordibility'] + self.bias
        return sigmoid_numpy(weighted_sum)
    
    def gradient_descent(self, age, affordibility, y_true, epochs, loss_threshold):
        #w1, w2, bias
        w1 = w2 = 1  #Initialized weights as 1 (arbitrary)
        bias = 0 #Initialized bias as 0 (arbitrary)
        rate = 0.5
        n = len(age)
    
        for i in range(epochs):
            weighted_sum = w1 * age + w2 * affordibility + bias
            y_predicted = sigmoid_numpy(weighted_sum) #This is what neuron does
            loss = log_loss(y_true, y_predicted)
        
            w1d = (1/n)*np.dot(np.transpose(age), (y_predicted-y_true)) #w1 derivative
            w2d = (1/n)*np.dot(np.transpose(affordibility), (y_predicted-y_true)) #w1 derivative
            bias_d = np.mean(y_predicted-y_true)
        
            w1 = w1 - rate * w1d
            w2 = w2 - rate * w2d
            bias = bias - rate * bias_d
            if i %50==0:
                print(f'Epoch:{i}, w1:{w1}, w2:{w2}, bias:{bias}, loss:{loss}')
            
            if loss <= loss_threshold:
                print(f'Epoch:{i}, w1:{w1}, w2:{w2}, bias:{bias}, loss:{loss}')
                break
        return w1, w2, bias

# %%
#Building NN from scratch
customModel = myNN()
customModel.fit(X_train_scaled, y_train, epochs=500, loss_threshold=0.4631)
# Out:
# Epoch:0, w1:0.9861310900087829, w2:0.9667920498214876, bias:-0.08519171257170967, loss:0.6610714463450795
# Epoch:50, w1:1.5571500488594048, w2:1.0922689682011197, bias:-0.992027332236758, loss:0.5702946539651738
# Epoch:100, w1:2.239060715863298, w2:1.21042980438863, bias:-1.3452275339230715, loss:0.5459194352704301
# Epoch:150, w1:2.8644913120725644, w2:1.2463829077726976, bias:-1.6183484677094964, loss:0.5271441264632641
# Epoch:200, w1:3.4311965874074075, w2:1.256232620215434, bias:-1.8490750278918544, loss:0.512101026512051
# Epoch:250, w1:3.9428749979160607, w2:1.2589166378735217, bias:-2.052158922361808, loss:0.49992931164520055
# Epoch:300, w1:4.404876998896, w2:1.2606135429729877, bias:-2.2342382764459856, loss:0.4900265016461037
# Epoch:350, w1:4.8226481797164515, w2:1.263102345349418, bias:-2.3989104335306473, loss:0.48192950704800824
# Epoch:400, w1:5.201203008943443, w2:1.2666878956499086, bias:-2.5485342927819183, loss:0.47527681081793055
# ...

# %%
coef, intercept #w1, w2 and bias came really close with tensorflow
# Out:
# (array([[5.634472],
#         [1.269317]], dtype=float32),
#  array([-2.7159626], dtype=float32))

# %%
customModel.predict(X_test_scaled)
# Out:
# 2     0.772011
# 10    0.382878
# 21    0.216606
# 11    0.526934
# 14    0.791954
# 9     0.884829
# dtype: float64

# %%
model.predict(X_test_scaled) #Again really close with tensorflow
# Out:
# array([[0.76880145],
#        [0.39354372],
#        [0.22252706],
#        [0.53270483],
#        [0.7882227 ],
#        [0.87978363]], dtype=float32)
